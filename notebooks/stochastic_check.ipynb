# %%
from erna.toy_data.toy_graph_1 import toy_graph_1
import networkx as nx
import igraph as ig

# %%
nxg = toy_graph_1.to_networkx_graph()

# %%
nx.draw(nxg, with_labels=True)

# %%
igg = toy_graph_1.to_igraph()

# %%
ig.plot(igg)

# %%
igg.vs[0]
# Out:
# igraph.Vertex(<igraph.Graph object at 0x70054060b640>, 0, {'name': 0, 'census': [{'group': 'A', 'num_inhabitants': 100, 'median_hhi': 10000.0}, {'group': 'B', 'num_inhabitants': 20, 'median_hhi': 50000.0}]})
